# %% [markdown]
# *Instalación de librerias necesarias.*
#
# Solo se debe correr una única vez.

# %%
# !pip install covid
# !pip install pycountry
# !pip install plotly
# !pip install wget
# !pip install deep-translator
# !pip install nltk
# !pip install pandas
# !pip install numpy
# !pip install opencv-python
# !pip install unicodedata2
# !pip install pyaudio
# !pip install pyttsx3
# !pip install os-win
# !pip install string
# !pip install random
# !pip install os-sys

# %% [markdown]
# **Corre la celda de abajo para interactuar con MMNBot.
# Puedes interactuar con el de forma normal, solo intenta seguir la corriente.**
#
#
# ---
# ![](https://i.pinimg.com/originals/0c/67/5a/0c675a8e1061478d2b7b21b330093444.gif)

# %%
#@title MMN Chatbot
#@markdown ![Esta es una imagen de ejemplo](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRGbLPwoNkbvHyZMHYn5F-8gnr2rF7BPKXnFw&usqp=CAU)
import chatVR as c
c.chatear("D:/GitHub/")
# Out:
# Qué tál! Soy tu amigo MMN Bot! ¿Cuál es tu nombre?:
#
# Estoy escuchando...
# INPUT : 	Hola Mi nombre es Natalia
# CHATBOT: 	Me caes bien, puedo recomendarte algo académico, algo de entretenimiento o de Covid, ¿cuál prefieres?
# Estoy escuchando...
# Procesando...
# Reconocido.
# NATALIA: 	entretenimiento
# CHATBOT:
# Muy bien, entretenimiento, podríamos empezar por:
#
# CHATBOT:
#  - Videos
#  - Películas
#  - Series
#  - Música
#  - Libros
#  - Videojuegos
# Estoy escuchando...
# Procesando...
# Reconocido.
# NATALIA: 	por videojuegos
# CHATBOT:
# ¿Qué clase de videojuegos te gustan?, ¿qué plataforma usas?
#
# CHATBOT:
#  Categorías:	 Consolas:
#  - Acción	 + Xbox
#  - Aventuras	 + PlayStation
#  - Carreras	 + Wii
#  - Deportes	 + Computadora
#  - Disparos
#  - Estrategia
#  - Peleas
#  - Plataforma
#  - Roles
#  - Rompecabezas
#  - Simulacion
#  - Variado
# Estoy escuchando...
# Procesando...
# Reconocido.
# NATALIA: 	PlayStation Store
# CHATBOT:
# Hum... creo que no capté algo de lo que dijiste, ¿podrías repetirlo?
# CHATBOT:
# Genial!, dime una categoría y plataforma.
#
# CHATBOT:
#  Categorías:	 Consolas:
#  - Acción	 + Xbox
#  - Aventuras	 + PlayStation
#  - Carreras	 + Wii
#  - Deportes	 + Computadora
#  - Disparos
#  - Estrategia
#  - Peleas
#  - Plataforma
#  - Roles
#  - Rompecabezas
#  - Simulacion
#  - Variado
# Estoy escuchando...
# Procesando...
# Reconocido.
# NATALIA: 	PlayStation y rompecabezas
# CHATBOT:
# Si te gusta la categoría de rompecabezas yo te recomendaría "Breakout", para PS.
# CHATBOT:
# []
# CHATBOT: 	Genial, un gusto hablar contigo ¿quieres continuar conversando?
# Estoy escuchando...
# Procesando...
# Reconocido.
# NATALIA: 	así
# CHATBOT: 	Me caes bien, puedo recomendarte algo académico, algo de entretenimiento o de Covid, ¿cuál prefieres?
# Estoy escuchando...
# Procesando...
# Reconocido.
# NATALIA: 	académico
# CHATBOT:
# Tengo distintas recomendaciones académicas, algunas son:
#
# CHATBOT:
#  - Artículos
#  - Investigadores
#  - Definiciones
# Estoy escuchando...
# Procesando...
# Reconocido.
# NATALIA: 	investigadores
# CHATBOT:
# ¿Que área del conocimiento te agrada en este momento?, estas son:
#
# CHATBOT:
#  - Fisica, Matemáticas y Ciencias de la Tierra
#  - Biología y Química
#  - Medicina y Ciencias de la Salud
#  - Humanidades y Ciencias de la Conducta
#  - Ciencias Sociales
#  - Biotecnología y Ciencias Agropecuarias
#  - Ingenierias
# Estoy escuchando...
# Procesando...
# Reconocido.
# NATALIA: 	matemáticas
# CHATBOT:
# Si te gusta el área de Área I: FISICO-MATEMÁTICAS Y CIENCIAS DE LA TIERRA yo te recomendaría contactar o buscar el trabajo
# desarrollado por "DRA. NINGOMBAM sin apellido Materno CHANDRACHANI DEVI", adscrito a Sin Institución
# CHATBOT: 	Genial, un gusto hablar contigo ¿quieres continuar conversando?
# Estoy escuchando...
# Procesando...
# Reconocido.
# NATALIA: 	no
# CHATBOT: 	Adios!
